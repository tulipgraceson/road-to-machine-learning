# %% [markdown]
# <a href="https://colab.research.google.com/github/tulipgraceson/road-to-machine-learning/blob/master/Predicting_quality_of_redwine_using_multi_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("winequality-red.csv")
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values
print(x)
print(y)
# Out:
# [[ 7.4    0.7    0.    ...  3.51   0.56   9.4  ]
#  [ 7.8    0.88   0.    ...  3.2    0.68   9.8  ]
#  [ 7.8    0.76   0.04  ...  3.26   0.65   9.8  ]
#  ...
#  [ 6.3    0.51   0.13  ...  3.42   0.75  11.   ]
#  [ 5.9    0.645  0.12  ...  3.57   0.71  10.2  ]
#  [ 6.     0.31   0.47  ...  3.39   0.66  11.   ]]
# [5 5 5 ... 6 5 6]

# %% [markdown]
# # cleaning

# %%
from sklearn.impute import SimpleImputer
sc=SimpleImputer(missing_values=np.nan,strategy="mean")
sc.fit(x[:,:-1])
x[:,:-1]=sc.transform(x[:,:-1])

# %% [markdown]
# # splitting of the data set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # training the model

# %%
from sklearn.linear_model import LinearRegression
rg=LinearRegression()
rg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # prediction time

# %%
rg.predict(x_test)
# Out:
# array([5.53665503, 5.3757028 , 6.09994909, 5.7271783 , 6.68879378,
#        5.97168959, 6.19501591, 5.0949962 , 5.78560446, 5.16051207,
#        6.18938201, 5.3458751 , 5.56153145, 6.48086642, 5.62134947,
#        5.34994932, 5.96750537, 5.42356559, 5.60694483, 5.41711492,
#        5.73487774, 6.17637761, 5.37367225, 6.41905085, 5.44448873,
#        6.30767106, 6.09458407, 5.68011379, 5.30702362, 5.83089423,
#        5.26785033, 6.38597599, 5.21408686, 6.30405167, 4.93102342,
#        5.71810813, 5.28395579, 5.36258835, 6.36476545, 5.06531698,
#        6.06709542, 5.05867037, 5.20044998, 6.14658841, 5.12300708,
#        5.7678295 , 5.10673949, 5.2573674 , 5.10344829, 6.03703173,
#        5.66043957, 5.45202212, 6.23953602, 4.83756366, 5.08496714,
#        5.9723325 , 6.05798102, 5.94793992, 5.85472477, 5.26350735,
#        6.32176985, 5.18819282, 5.28551904, 5.53125142, 4.63176391,
#        5.42415578, 6.67633306, 5.69037958, 5.76768184, 6.44320399,
# ...
